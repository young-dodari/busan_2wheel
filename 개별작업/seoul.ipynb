# %%
import pandas as pd

# %%
ab = pd.read_csv('./data/accidentInfoList.csv',encoding='utf-8')
ab
# Out:
#                     사고일시             시군구  사고내용  사망자수  중상자수  경상자수  부상신고자수  \
# 0        2019년 1월 1일 02시   서울특별시 서초구 방배동  중상사고     0     1     0       0
# 1        2019년 1월 1일 06시   서울특별시 노원구 월계동  중상사고     0     1     0       0
# 2        2019년 1월 1일 07시  서울특별시 강남구 압구정동  중상사고     0     1     1       0
# 3        2019년 1월 1일 12시    서울특별시 중랑구 묵동  중상사고     0     1     0       0
# 4        2019년 1월 1일 12시   서울특별시 강동구 천호동  중상사고     0     1     0       0
# ...                  ...             ...   ...   ...   ...   ...     ...
# 26143  2021년 12월 31일 19시   서울특별시 양천구 신정동  중상사고     0     1     0       0
# 26144  2021년 12월 31일 20시  서울특별시 중구 충무로4가  중상사고     0     1     0       0
# 26145  2021년 12월 31일 21시   서울특별시 마포구 서교동  중상사고     0     1     0       0
# 26146  2021년 12월 31일 21시   서울특별시 강남구 세곡동  중상사고     0     1     0       0
# 26147  2021년 12월 31일 22시   서울특별시 서초구 반포동  중상사고     0     1     1       0
#
#       가해운전자 차종 가해운전자 상해정도 피해운전자 차종 피해운전자 상해정도
# ...

# %%
ab = ab[(ab['가해운전자 차종'] == '이륜') | (ab['피해운전자 차종'] == '이륜')]

# %%
ab = ab.reset_index()

# %%
ab.to_csv('seoulAccidentInfoList.csv',encoding='utf-8')
