# %%
import pandas as pd
import folium
import json

# %%
df = pd.read_csv('./데이터/이륜차_사고다발지정보.csv')
df.tail()
# Out:
#      사고다발지FID  사고다발지ID       법정동코드      지점코드         시도시군구명  \
# 554    104405  2020058  4825010700  48250001      경상남도 김해시1
# 555    104473  2020058  4825011800  48250002      경상남도 김해시2
# 556    104407  2020058  4833025300  48330001      경상남도 양산시1
# 557    104250  2020058  4833025300  48330002      경상남도 양산시2
# 558    104483  2020058  5013010100  50130001  제주특별자치도 서귀포시1
#
#                               지점명  발생건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 554     경상남도 김해시 삼계동(부산은행앞교차로 부근)    15    18     0     9     9       0
# 555  경상남도 김해시 어방동(다솜조명백화점앞교차로 부근)    15    17     0     8     8       1
# 556       경상남도 양산시 물금읍(청운로188 부근)    15    20     0     9     8       3
# 557   경상남도 양산시 물금읍(양산부산대학교병원앞 부근)    15    17     0     4    11       2
# 558    제주특별자치도 서귀포시 서귀동(중앙로타리 부근)    17    23     0    12     8       3
#
#              경도         위도                                            다발지역폴리곤
# 554  128.870141  35.260576  {"type":"Polygon","coordinates":[[[128.8712402...
# 555  128.904049  35.242462  {"type":"Polygon","coordinates":[[[128.9051475...
# 556  129.003106  35.317060  {"type":"Polygon","coordinates":[[[129.0042060...
# 557  129.006555  35.330397  {"type":"Polygon","coordinates":[[[129.0076546...
# 558  126.560894  33.253077  {"type":"Polygon","coordinates":[[[126.5619677...

# %%
df['시'] = df['시도시군구명'].str.split().str.get(0)
df
# Out:
#      사고다발지FID  사고다발지ID       법정동코드      지점코드         시도시군구명  \
# 0      104688  2020058  1111017500  11110001     서울특별시 종로구1
# 1      104683  2020058  1111017400  11110002     서울특별시 종로구2
# 2      104684  2020058  1111016400  11110003     서울특별시 종로구3
# 3      104573  2020058  1111016500  11110004     서울특별시 종로구4
# 4      104773  2020058  1111016100  11110005     서울특별시 종로구5
# ..        ...      ...         ...       ...            ...
# 554    104405  2020058  4825010700  48250001      경상남도 김해시1
# 555    104473  2020058  4825011800  48250002      경상남도 김해시2
# 556    104407  2020058  4833025300  48330001      경상남도 양산시1
# 557    104250  2020058  4833025300  48330002      경상남도 양산시2
# 558    104483  2020058  5013010100  50130001  제주특별자치도 서귀포시1
#
#                                 지점명  발생건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0            서울특별시 종로구 숭인동(동묘앞역 부근)    43    53     0    19    27       7
# 1          서울특별시 종로구 창신동(오간수교남단 부근)    28    33     0     6    16      11
# 2         서울특별시 종로구 종로6가(동대문로터리 부근)    25    28     0     6    13       9
# 3           서울특별시 종로구 이화동(이화사거리 부근)    24    24     0     9    12       3
# 4    서울특별시 종로구 종로4가(종로4가일반국도6호선 부근)    21    31     0    12    16       3
# ..                              ...   ...   ...   ...   ...   ...     ...
# 554       경상남도 김해시 삼계동(부산은행앞교차로 부근)    15    18     0     9     9       0
# 555    경상남도 김해시 어방동(다솜조명백화점앞교차로 부근)    15    17     0     8     8       1
# 556         경상남도 양산시 물금읍(청운로188 부근)    15    20     0     9     8       3
# 557     경상남도 양산시 물금읍(양산부산대학교병원앞 부근)    15    17     0     4    11       2
# 558      제주특별자치도 서귀포시 서귀동(중앙로타리 부근)    17    23     0    12     8       3
#
#              경도         위도                                            다발지역폴리곤  \
# 0    127.015644  37.573022  {"type":"Polygon","coordinates":[[[127.0167759...
# 1    127.009633  37.569467  {"type":"Polygon","coordinates":[[[127.0107653...
# 2    127.008737  37.571310  {"type":"Polygon","coordinates":[[[127.0098693...
# 3    127.002189  37.576176  {"type":"Polygon","coordinates":[[[127.0033209...
# 4    126.997298  37.570828  {"type":"Polygon","coordinates":[[[126.9984304...
# ..          ...        ...                                                ...
# 554  128.870141  35.260576  {"type":"Polygon","coordinates":[[[128.8712402...
# 555  128.904049  35.242462  {"type":"Polygon","coordinates":[[[128.9051475...
# 556  129.003106  35.317060  {"type":"Polygon","coordinates":[[[129.0042060...
# 557  129.006555  35.330397  {"type":"Polygon","coordinates":[[[129.0076546...
# 558  126.560894  33.253077  {"type":"Polygon","coordinates":[[[126.5619677...
#
#            시
# 0      서울특별시
# 1      서울특별시
# 2      서울특별시
# 3      서울특별시
# 4      서울특별시
# ..       ...
# 554     경상남도
# 555     경상남도
# 556     경상남도
# 557     경상남도
# 558  제주특별자치도
#
# [559 rows x 16 columns]

# %%
df_seoul = df[df['시']=='서울특별시']
df_seoul
# Out:
#      사고다발지FID  사고다발지ID       법정동코드      지점코드      시도시군구명  \
# 0      104688  2020058  1111017500  11110001  서울특별시 종로구1
# 1      104683  2020058  1111017400  11110002  서울특별시 종로구2
# 2      104684  2020058  1111016400  11110003  서울특별시 종로구3
# 3      104573  2020058  1111016500  11110004  서울특별시 종로구4
# 4      104773  2020058  1111016100  11110005  서울특별시 종로구5
# ..        ...      ...         ...       ...         ...
# 280    104429  2020058  1174010500  11740001  서울특별시 강동구1
# 281    104501  2020058  1174010900  11740002  서울특별시 강동구2
# 282    104355  2020058  1174010900  11740003  서울특별시 강동구3
# 283    104492  2020058  1174010900  11740004  서울특별시 강동구4
# 284    104497  2020058  1174010500  11740005  서울특별시 강동구5
#
#                                 지점명  발생건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0            서울특별시 종로구 숭인동(동묘앞역 부근)    43    53     0    19    27       7
# 1          서울특별시 종로구 창신동(오간수교남단 부근)    28    33     0     6    16      11
# 2         서울특별시 종로구 종로6가(동대문로터리 부근)    25    28     0     6    13       9
# 3           서울특별시 종로구 이화동(이화사거리 부근)    24    24     0     9    12       3
# 4    서울특별시 종로구 종로4가(종로4가일반국도6호선 부근)    21    31     0    12    16       3
# ..                              ...   ...   ...   ...   ...   ...     ...
# 280          서울특별시 강동구 길동(길동사거리 부근)    18    26     1    10    11       4
# 281         서울특별시 강동구 천호동(천호동공원 부근)    16    18     0     7    10       1
# 282          서울특별시 강동구 천호동(유미벅스 부근)    15    15     0    10     2       3
# 283          서울특별시 강동구 천호동(천호시장 부근)    15    19     0     4    10       5
# 284         서울특별시 강동구 길동(강동성심병원 부근)    15    18     0     3    11       4
#
#              경도         위도                                            다발지역폴리곤  \
# 0    127.015644  37.573022  {"type":"Polygon","coordinates":[[[127.0167759...
# 1    127.009633  37.569467  {"type":"Polygon","coordinates":[[[127.0107653...
# 2    127.008737  37.571310  {"type":"Polygon","coordinates":[[[127.0098693...
# 3    127.002189  37.576176  {"type":"Polygon","coordinates":[[[127.0033209...
# 4    126.997298  37.570828  {"type":"Polygon","coordinates":[[[126.9984304...
# ..          ...        ...                                                ...
# 280  127.138348  37.534074  {"type":"Polygon","coordinates":[[[127.1394795...
# 281  127.125960  37.545594  {"type":"Polygon","coordinates":[[[127.1270919...
# 282  127.131660  37.538434  {"type":"Polygon","coordinates":[[[127.1327914...
# 283  127.127881  37.540360  {"type":"Polygon","coordinates":[[[127.1290126...
# 284  127.134211  37.535161  {"type":"Polygon","coordinates":[[[127.1353429...
#
#          시
# 0    서울특별시
# 1    서울특별시
# 2    서울특별시
# 3    서울특별시
# 4    서울특별시
# ..     ...
# 280  서울특별시
# 281  서울특별시
# 282  서울특별시
# 283  서울특별시
# 284  서울특별시
#
# [285 rows x 16 columns]

# %%
condition = (df_seoul['발생건수'] >= 18)

df_seoul1 =df_seoul.loc[condition]
df_seoul1
# Out:
#      사고다발지FID  사고다발지ID       법정동코드      지점코드      시도시군구명  \
# 0      104688  2020058  1111017500  11110001  서울특별시 종로구1
# 1      104683  2020058  1111017400  11110002  서울특별시 종로구2
# 2      104684  2020058  1111016400  11110003  서울특별시 종로구3
# 3      104573  2020058  1111016500  11110004  서울특별시 종로구4
# 4      104773  2020058  1111016100  11110005  서울특별시 종로구5
# ..        ...      ...         ...       ...         ...
# 271    104466  2020058  1171010100  11710006  서울특별시 송파구6
# 272    104455  2020058  1171010400  11710007  서울특별시 송파구7
# 273    104456  2020058  1171011300  11710008  서울특별시 송파구8
# 274    104467  2020058  1171010400  11710009  서울특별시 송파구9
# 280    104429  2020058  1174010500  11740001  서울특별시 강동구1
#
#                                 지점명  발생건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0            서울특별시 종로구 숭인동(동묘앞역 부근)    43    53     0    19    27       7
# 1          서울특별시 종로구 창신동(오간수교남단 부근)    28    33     0     6    16      11
# 2         서울특별시 종로구 종로6가(동대문로터리 부근)    25    28     0     6    13       9
# 3           서울특별시 종로구 이화동(이화사거리 부근)    24    24     0     9    12       3
# 4    서울특별시 종로구 종로4가(종로4가일반국도6호선 부근)    21    31     0    12    16       3
# ..                              ...   ...   ...   ...   ...   ...     ...
# 271           서울특별시 송파구 잠실동(신천역 부근)    20    24     0     6    15       3
# 272         서울특별시 송파구 송파동(송파사거리 부근)    19    20     0    10     6       4
# 273      서울특별시 송파구 거여동(거여역거여사거리 부근)    19    24     0     7    11       6
# 274           서울특별시 송파구 송파동(석촌역 부근)    19    21     0     6    12       3
# 280          서울특별시 강동구 길동(길동사거리 부근)    18    26     1    10    11       4
#
#              경도         위도                                            다발지역폴리곤  \
# 0    127.015644  37.573022  {"type":"Polygon","coordinates":[[[127.0167759...
# 1    127.009633  37.569467  {"type":"Polygon","coordinates":[[[127.0107653...
# 2    127.008737  37.571310  {"type":"Polygon","coordinates":[[[127.0098693...
# 3    127.002189  37.576176  {"type":"Polygon","coordinates":[[[127.0033209...
# 4    126.997298  37.570828  {"type":"Polygon","coordinates":[[[126.9984304...
# ..          ...        ...                                                ...
# 271  127.085485  37.511290  {"type":"Polygon","coordinates":[[[127.0866167...
# 272  127.110367  37.501979  {"type":"Polygon","coordinates":[[[127.1114980...
# 273  127.144491  37.493172  {"type":"Polygon","coordinates":[[[127.1456220...
# 274  127.106960  37.505318  {"type":"Polygon","coordinates":[[[127.1080915...
# 280  127.138348  37.534074  {"type":"Polygon","coordinates":[[[127.1394795...
#
#          시
# 0    서울특별시
# 1    서울특별시
# 2    서울특별시
# 3    서울특별시
# 4    서울특별시
# ..     ...
# 271  서울특별시
# 272  서울특별시
# 273  서울특별시
# 274  서울특별시
# 280  서울특별시
#
# [152 rows x 16 columns]

# %%
df_seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 285 entries, 0 to 284
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   사고다발지FID  285 non-null    int64
#  1   사고다발지ID   285 non-null    int64
#  2   법정동코드     285 non-null    int64
#  3   지점코드      285 non-null    int64
#  4   시도시군구명    285 non-null    object
#  5   지점명       285 non-null    object
#  6   발생건수      285 non-null    int64
#  7   사상자수      285 non-null    int64
#  8   사망자수      285 non-null    int64
#  9   중상자수      285 non-null    int64
#  10  경상자수      285 non-null    int64
#  11  부상신고자수    285 non-null    int64
#  12  경도        285 non-null    float64
#  13  위도        285 non-null    float64
#  14  다발지역폴리곤   285 non-null    object
#  15  시         285 non-null    object
# dtypes: float64(2), int64(10), object(4)
# memory usage: 46.0+ KB

# %%
map = folium.Map((37.558480,126.977420), zoom_start=11)
for i in df_seoul1.index:
    lat = df_seoul1.loc[i, '위도']
    long = df_seoul1.loc[i, '경도']
    folium.CircleMarker([lat,long],
                    tooltip= df_seoul1.loc[i,'지점명'],
                    color='red',
                    fill=True
                    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f76210c60310d59e4fee8723bad94a0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f76210c60310d59e4fee8723bad94a0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f76210c60310d59e4fee8723bad94a0d = L.map(
#                 &quot;map_f76210c60310d59e4fee8723bad94a0d&quot;,
#                 {
#                     center: [37.55848, 126.97742],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aff57600e50bbb5bee9df34930ef89aa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f76210c60310d59e4fee8723bad94a0d);
#
#
#             var circle_marker_fdf79b50de6bf005797766e387c88506 = L.circleMarker(
#                 [37.57302201, 127.0156436],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f76210c60310d59e4fee8723bad94a0d);
#
#
#             circle_marker_fdf79b50de6bf005797766e387c88506.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 종로구 숭인동(동묘앞역 부근)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_af2f7661de43f148b332081030804ae7 = L.circleMarker(
#                 [37.56946748, 127.009633],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f76210c60310d59e4fee8723bad94a0d);
#
#
#             circle_marker_af2f7661de43f148b332081030804ae7.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 종로구 창신동(오간수교남단 부근)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_2db544a603dc47e4f327e0851acc0f58 = L.circleMarker(
#                 [37.5713096, 127.0087369],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f76210c60310d59e4fee8723bad94a0d);
#
#
#             circle_marker_2db544a603dc47e4f327e0851acc0f58.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 종로구 종로6가(동대문로터리 부근)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b65c1f99dd8603211c01d7a1bbc466b3 = L.circleMarker(
#                 [37.57617605, 127.0021885],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f76210c60310d59e4fee8723bad94a0d);
#
#
#             circle_marker_b65c1f99dd8603211c01d7a1bbc466b3.bindTooltip(
#                 `&lt;div&gt;
#                      서울특별시 종로구 이화동(이화사거리 부근)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_b4a99ec6b9f81771b95616bbf0205927 = L.circleMarker(
#                 [37.57082837, 126.9972981],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&qu

# %%
map = folium.Map([37.558480,126.977420], zoom_start=12, )

for i in df_seoul.index:
    sub_lat = df_seoul.loc[i, "위도"]
    sub_long = df_seoul.loc[i, "경도"]
    
    title = f"{df_seoul.loc[i, '상호명']} - {df_seoul.loc[i, '도로명주소']}"

map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\admin\Desktop\프로젝트데이터수정작업용\사고다발지가공.ipynb 셀 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/admin/Desktop/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%88%98%EC%A0%95%EC%9E%91%EC%97%85%EC%9A%A9/%EC%82%AC%EA%B3%A0%EB%8B%A4%EB%B0%9C%EC%A7%80%EA%B0%80%EA%B3%B5.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> map = folium.Map([37.558480,126.977420], zoom_start=12, )
#       <a href='vscode-notebook-cell:/c%3A/Users/admin/Desktop/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%88%98%EC%A0%95%EC%9E%91%EC%97%85%EC%9A%A9/%EC%82%AC%EA%B3%A0%EB%8B%A4%EB%B0%9C%EC%A7%80%EA%B0%80%EA%B3%B5.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> for i in df_seoul.index:
#       <a href='vscode-notebook-cell:/c%3A/Users/admin/Desktop/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%88%98%EC%A0%95%EC%9E%91%EC%97%85%EC%9A%A9/%EC%82%AC%EA%B3%A0%EB%8B%A4%EB%B0%9C%EC%A7%80%EA%B0%80%EA%B3%B5.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     sub_lat = df_seoul.loc[i, "위도"]
#
# NameError: name 'folium' is not defined
